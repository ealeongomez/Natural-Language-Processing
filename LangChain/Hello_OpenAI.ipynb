# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage

# Cargar variables de entorno desde .env
load_dotenv()

# Verificar que la API key se cargó correctamente
if not os.getenv("OPENAI_API_KEY"):
    raise ValueError("❌ No se encontró OPENAI_API_KEY en el archivo .env")
else:
    print("✅ API key de OpenAI cargada correctamente")
# Out:
# ✅ API key de OpenAI cargada correctamente

# %%
llm = ChatOpenAI(model="gpt-3.5-turbo", temperature=0.7)

# %%
response = llm.invoke("¡Hola! ¿Cómo estás?")
print(response.content)
# Out:
# ¡Hola! Estoy bien, gracias. ¿Y tú? ¿Cómo estás?

# %%
messages = [
    SystemMessage(content="Eres un asistente amigable que responde en español."),
    HumanMessage(content="Cuéntame un dato interesante sobre Python")
]
response = llm.invoke(messages)
print(response.content)
# Out:
# Un dato interesante sobre Python es que es uno de los lenguajes de programación más populares y utilizados en la actualidad. Su sintaxis clara y legible, así como su versatilidad y facilidad de aprendizaje, lo han convertido en una herramienta muy popular tanto para principiantes como para programadores experimentados. Además, Python es utilizado en una gran variedad de aplicaciones, desde desarrollo web y análisis de datos hasta inteligencia artificial y aprendizaje automático.
